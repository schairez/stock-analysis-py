# %%
import pandas as pd
import json
import plotly.graph_objects as go
import plotly as py
import plotly.io as pio
# import plotly.offline as py
# py.init_notebook_mode() # graphs charts inline (IPython).
from datetime import datetime
#local imports
from json_to_df import df_from_response

# %%
# pio.templates.default = "plotly_dark"

# %%
aapl_df = df_from_response('data_aapl.json')

# %%
aapl_df.dtypes
# Out:
# Date                    datetime64[ns]
# Open                           float64
# High                           float64
# Low                            float64
# Close                          float64
# AdjClose                       float64
# Volume                           int64
# 7. dividend amount              object
# 8. split coefficient            object
# AdjFactor                      float64
# AdjOpen                        float64
# AdjHigh                        float64
# AdjLow                         float64
# dtype: object

# %%
aapl_df['Date']
# Out:
# 0      2020-05-06
# 1      2020-05-05
# 2      2020-05-04
# 3      2020-05-01
# 4      2020-04-30
#           ...
# 5027   2000-05-11
# 5028   2000-05-10
# 5029   2000-05-09
# 5030   2000-05-08
# 5031   2000-05-05
# Name: Date, Length: 5032, dtype: datetime64[ns]

# %%
hovertext=[]
for i in range(len(aapl_df['Open'])):
    hovertext.append(
       aapl_df['Date'][i].strftime("%m/%d/%Y") + 
    '<br>O: '+str(round(aapl_df['AdjOpen'][i],4)) + 
    '\tH: '+str(round(aapl_df['AdjHigh'][i],4)) + 
    '<br>L: '+str(round(aapl_df['AdjLow'][i],4)) + 
    '\tC: '+str(aapl_df['AdjClose'][i]))


fig = go.Figure(data=go.Candlestick(x=aapl_df['Date'],
                    open=aapl_df['AdjOpen'],
                    high=aapl_df['AdjHigh'],
                    low=aapl_df['AdjLow'],
                    close=aapl_df['AdjClose'],
                    text=hovertext,
                    hoverinfo='text'),
                    layout=go.Layout(
                        title="AAPL Stock",
                        width=1200,
                        height=600,
                        xaxis_rangeslider_visible=False)
                        )
fig.update_xaxes(
    rangebreaks=[
        dict(bounds=["sat", "mon"]), #hide weekends
        dict(values=["2015-12-25", "2016-01-01"])  # hide Christmas and New Year's
    ]
)


# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=False
        ),
        type="date"
    )
)



# fig.update_layout(title="AAPL Stock", xaxis_rangeslider_visible=False)
# fig.update_layout(xaxis_rangeslider_visible=False)

fig.show()

#NOTE
#AAPL (Apple Inc) Stock Split 1:7 in 2014-06-09

# %%
def plot_ohlc(co_df:pd.DataFrame):

    hovertext=[]
    for i in range(len(aapl_df['Open'])):
        hovertext.append(
        aapl_df['Date'][i].strftime("%m/%d/%Y") + 
        '<br>O: '+str(round(aapl_df['AdjOpen'][i],4)) + 
        '\tH: '+str(round(aapl_df['AdjHigh'][i],4)) + 
        '<br>L: '+str(round(aapl_df['AdjLow'][i],4)) + 
        '\tC: '+str(aapl_df['AdjClose'][i]))


    fig = go.Figure(data=go.Candlestick(x=aapl_df['Date'],
                        open=aapl_df['AdjOpen'],
                        high=aapl_df['AdjHigh'],
                        low=aapl_df['AdjLow'],
                        close=aapl_df['AdjClose'],
                        text=hovertext,
                        hoverinfo='text'),
                        layout=go.Layout(
                            title="AAPL Stock",
                            width=1200,
                            height=600,
                            xaxis_rangeslider_visible=False)
                            )
    fig.update_xaxes(
        rangebreaks=[
            dict(bounds=["sat", "mon"]), #hide weekends
            dict(values=["2015-12-25", "2016-01-01"])  # hide Christmas and New Year's
        ]
    )


    # Add range slider
    fig.update_layout(
        xaxis=dict(
            rangeselector=dict(
                buttons=list([
                    dict(count=1,
                        label="1m",
                        step="month",
                        stepmode="backward"),
                    dict(count=6,
                        label="6m",
                        step="month",
                        stepmode="backward"),
                    dict(count=1,
                        label="YTD",
                        step="year",
                        stepmode="todate"),
                    dict(count=1,
                        label="1y",
                        step="year",
                        stepmode="backward"),
                    dict(step="all")
                ])
            ),
            rangeslider=dict(
                visible=False
            ),
            type="date"
        )
    )



    # fig.update_layout(title="AAPL Stock", xaxis_rangeslider_visible=False)
    # fig.update_layout(xaxis_rangeslider_visible=False)

    fig.show()
